# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data.csv')
data
# Out:
#      ID                Name   Age Gender                 Phone  \
# 0   177        James Rhodes  52.0      M          504.554.3776
# 1   984   Kimberly Crawford  56.0    NaN                   NaN
# 2   722        Karen Walker  59.0      M                   NaN
# 3   870        Sandra Smith   NaN      M      479.487.9989x242
# 4   664        Alison Walsh  77.0      M      001-879-250-3309
# 5   375      Tracy Martinez  41.0      M      510-232-7358x300
# 6   582       Melinda Moore  58.0      F          881.432.9428
# 7    65      William Barnes   NaN      F            2879941085
# 8    52         James Smith   NaN      M   (695)406-9894x90477
# 9   811    Theresa Woods MD  41.0    NaN            5716794807
# 10  497  Stephanie Mcdonald  78.0      M         (213)445-6777
# 11  747        Andrea Jones  42.0      M  +1-400-696-8787x6689
# 12  159     Joshua Odonnell  40.0      F   +1-906-322-0072x276
# 13  370        Sarah Guerra  43.0      M         (693)989-4358
# 14  874           Tara Barr  30.0      F          357.864.0856
#
#                          Email  \
# 0       fostergina@example.com
# 1         krussell@example.com
# 2      kiarapeters@example.net
# 3         rodney99@example.net
# 4         denglish@example.com
# 5   dylandominguez@example.com
# 6           john46@example.net
# 7    vancemeredith@example.com
# 8     devinkennedy@example.org
# 9      jacksonjack@example.org
# 10        ugriffin@example.net
# 11     bairdshawna@example.org
# 12          chicks@example.net
# 13          bheath@example.org
# 14    nicholasking@example.com
#
#                                               Address Credit_Score  \
# 0   3892 Kathleen Square Apt. 817\nLake Jill, AZ 1...      unknown
# 1      51987 Bush Ranch Suite 663\nScottton, PA 03611          700
# 2       29197 Austin Flat\nEast Robertmouth, NE 42823          870
# 3            185 Le Villages\nPort Johnside, WY 42113      unknown
# 4   295 Matthew Inlet Suite 676\nJohnsonland, NC 4...      unknown
# 5     7639 Farmer Park Apt. 847\nNew Steven, MA 50197          798
# 6          05765 Jennifer Creek\nCamposland, KS 85868          842
# 7      8243 Burch Fords\nNorth Kennethhaven, WY 90915          793
# 8        59692 Lopez Crossing\nNorth Hannah, WY 99739          865
# 9                                                 NaN          855
# 10  108 Collins Villages Apt. 979\nEast Stephanie,...          715
# 11  786 Sarah Islands Suite 239\nSchmidtside, PR 0...          844
# 12            260 Dunlap Pike\nEscobarville, AR 49939          656
# 13     3529 Stephen Greens\nNorth Wendyfort, KS 86983          832
# 14  45618 Torres Underpass Suite 584\nSuzanneville...          541
#
#    Last_Purchase_Date
# 0          2021-09-19
# 1          2023-02-25
# 2          2021-09-17
# 3          2021-11-24
# 4          2022-05-08
# 5          2023-01-31
# 6          2022-07-17
# 7                 NaN
# 8          2021-11-22
# 9          2023-04-10
# 10         2021-11-27
# 11         2023-03-31
# 12         2022-02-27
# 13         2023-01-31
# 14         2023-06-25

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  15 non-null     int64
#  1   Name                15 non-null     object
#  2   Age                 12 non-null     float64
#  3   Gender              13 non-null     object
#  4   Phone               13 non-null     object
#  5   Email               15 non-null     object
#  6   Address             14 non-null     object
#  7   Credit_Score        15 non-null     object
#  8   Last_Purchase_Date  14 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.2+ KB

# %%
data['Age'] = data['Age'].astype('Int64')
median_age = data['Age'].median()
median_age = round(median_age)

data['Age'].fillna(median_age,inplace=True)

# %%
data['Gender'].fillna('Unknown',inplace=True)
data['Phone'].fillna('Unknown',inplace=True)
data['Address'].fillna('Unknown',inplace=True)

# %%
most_recent_date = pd.to_datetime(data['Last_Purchase_Date']).max()
data['Last_Purchase_Date'].fillna(most_recent_date,inplace=True)

# %%
data['Credit_Score'] = pd.to_numeric(data['Credit_Score'],
                                    errors='coerce')
mean_credit_score = data['Credit_Score'].mean()

data['Credit_Score'].fillna(mean_credit_score,inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      ID                Name  Age   Gender                 Phone  \
# 0   177        James Rhodes   52        M          504.554.3776
# 1   984   Kimberly Crawford   56  Unknown               Unknown
# 2   722        Karen Walker   59        M               Unknown
# 3   870        Sandra Smith   48        M      479.487.9989x242
# 4   664        Alison Walsh   77        M      001-879-250-3309
# 5   375      Tracy Martinez   41        M      510-232-7358x300
# 6   582       Melinda Moore   58        F          881.432.9428
# 7    65      William Barnes   48        F            2879941085
# 8    52         James Smith   48        M   (695)406-9894x90477
# 9   811    Theresa Woods MD   41  Unknown            5716794807
# 10  497  Stephanie Mcdonald   78        M         (213)445-6777
# 11  747        Andrea Jones   42        M  +1-400-696-8787x6689
# 12  159     Joshua Odonnell   40        F   +1-906-322-0072x276
# 13  370        Sarah Guerra   43        M         (693)989-4358
# 14  874           Tara Barr   30        F          357.864.0856
#
#                          Email  \
# 0       fostergina@example.com
# 1         krussell@example.com
# 2      kiarapeters@example.net
# 3         rodney99@example.net
# 4         denglish@example.com
# 5   dylandominguez@example.com
# 6           john46@example.net
# 7    vancemeredith@example.com
# 8     devinkennedy@example.org
# 9      jacksonjack@example.org
# 10        ugriffin@example.net
# 11     bairdshawna@example.org
# 12          chicks@example.net
# 13          bheath@example.org
# 14    nicholasking@example.com
#
#                                               Address  Credit_Score  \
# 0   3892 Kathleen Square Apt. 817\nLake Jill, AZ 1...    775.916667
# 1      51987 Bush Ranch Suite 663\nScottton, PA 03611    700.000000
# 2       29197 Austin Flat\nEast Robertmouth, NE 42823    870.000000
# 3            185 Le Villages\nPort Johnside, WY 42113    775.916667
# 4   295 Matthew Inlet Suite 676\nJohnsonland, NC 4...    775.916667
# 5     7639 Farmer Park Apt. 847\nNew Steven, MA 50197    798.000000
# 6          05765 Jennifer Creek\nCamposland, KS 85868    842.000000
# 7      8243 Burch Fords\nNorth Kennethhaven, WY 90915    793.000000
# 8        59692 Lopez Crossing\nNorth Hannah, WY 99739    865.000000
# 9                                             Unknown    855.000000
# 10  108 Collins Villages Apt. 979\nEast Stephanie,...    715.000000
# 11  786 Sarah Islands Suite 239\nSchmidtside, PR 0...    844.000000
# 12            260 Dunlap Pike\nEscobarville, AR 49939    656.000000
# 13     3529 Stephen Greens\nNorth Wendyfort, KS 86983    832.000000
# 14  45618 Torres Underpass Suite 584\nSuzanneville...    541.000000
#
#      Last_Purchase_Date
# 0            2021-09-19
# 1            2023-02-25
# 2            2021-09-17
# 3            2021-11-24
# 4            2022-05-08
# 5            2023-01-31
# 6            2022-07-17
# 7   2023-06-25 00:00:00
# 8            2021-11-22
# 9            2023-04-10
# 10           2021-11-27
# 11           2023-03-31
# 12           2022-02-27
# 13           2023-01-31
# 14           2023-06-25
